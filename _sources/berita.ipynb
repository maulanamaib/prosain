# %% [markdown]
# # Crawling Website Berita

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install html5lib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup
page = requests.get('https://www.antaranews.com/berita/3407430/malaysia-kutuk-peluncuran-rudal-balistik-korut?utm_source=antaranews&utm_medium=desktop&utm_campaign=terkini')
soup = BeautifulSoup(page.content, 'html5lib')
seven_day = soup.find(id="seven-day-forecast")
print (soup.prettify())
if page.status_code==200:
    div = soup.find(id='main-wrapper')
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Malaysia kutuk peluncuran rudal balistik Korut - ANTARA News
#   </title>
#   <meta content="Malaysia mengutuk peluncuran rudal balistik baru-baru ini oleh Korea Utara, termasuk peluncuran rudal balistik jarak antarbenua pada 18 Februari 2023. ..." name="description"/>
#   <meta content="antaranews.com" name="author"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta class="viewport" content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://m.antaranews.com/amp/berita/3407430/malaysia-kutuk-peluncuran-rudal-balistik-korut" rel="amphtml"/>
#   <link href="https://img.antaranews.com/cache/800x533/2023/02/20/2023-02-20T014634Z_650085075_RC2PEZ96XPK1_RTRMADP_3_NORTHKOREA-MISSILES.jpg" rel="image_src"/>
# ...

# %%
tittle=soup.h1
judul=tittle.get_text()
[judul]
# Out:
# ['Malaysia kutuk peluncuran rudal balistik Korut']

# %%
ps = soup.find_all('div' ,class_="post-content clearfix") #find all p tags
for p in ps:
   isi = p.get_text().strip()
   
print([isi])
# Out:
# ['Kuala Lumpur (ANTARA) - Malaysia mengutuk peluncuran rudal balistik baru-baru ini oleh Korea Utara, termasuk peluncuran rudal balistik jarak antarbenua pada 18 Februari 2023. \n\xa0\n\nKementerian Luar Negeri Malaysia dalam keterangan pers dikeluarkan di Putrajaya, Selasa, menyebutkan Malaysia sangat menyesalkan kejadian itu yang merupakan ancaman serius untuk perdamaian dan keamanan dunia. \n\xa0\n\nTindakan Korea Utara tersebut hanya akan semakin meningkatkan ketegangan regional dan menghambat prospek perdamaian abadi di Semenanjung Korea. \n\xa0\n\nMalaysia mendesak Korea Utara untuk menahan diri dari tindakan provokatif dan ilegal lebih lanjut, mematuhi kewajiban\xa0berdasarkan resolusi Dewan Keamanan PBB (DK PBB) yang relevan dengan komitmen internasional.\n\xa0\n\nMalaysia juga mendesak Korea Utara\xa0untuk segera menghentikan program rudal nuklir dan balistik. \n\xa0\n\nPernyataan itu juga menyebutkan bahwa sangat  penting bagi pihak- pihak terkait untuk melanjutkan dialog g
# ...

# %%
import pandas as pd
berita = pd.DataFrame({
    "judul Berita": [judul],
    "isi Berita": [isi],
  
})
 
berita
# Out:
#                                      judul Berita  \
# 0  Malaysia kutuk peluncuran rudal balistik Korut
#
#                                           isi Berita
# 0  Kuala Lumpur (ANTARA) - Malaysia mengutuk pelu...

# %%
from pathlib import Path  
filepath = Path('/content/drive/MyDrive/sainsdata/tugas/Berita.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
berita.to_csv(filepath)

# %% [markdown]
# #UDAH SAMPE INI AJA GAN, YANG DIBAWAH CUMAN NYOBA2:V

# %%
soup.p
# Out:
# <p>iam wisi quam lorem vestibulum nec nibh, sollicitudin volutpat at libero litora, non adipiscing. Nul...</p>

# %%
if page.status_code==200:
    div = soup.find(id='main-wrapper')

# %%
# articles = div.findAll('div', attrs = {'class':'post'})
# quotes = []
# for row in articles:
#    quote = {}
#    quote['judul'] = row.h3.text.replace('\n','')
#    quote['url'] = row.a['href']
#    quote['img'] = row.img['src']
#    quote['time'] = row.span.text.replace('\n','')
#    quotes.append(quote)

# %%
# import json
# import pprint

# pprint.pprint(quotes)
# Out:
# [{'img': 'https://1.bp.blogspot.com/-qzWnaiCGRNg/WY--jRTbVYI/AAAAAAAAArU/FIiunmSjiVQJUn7CYC-kMX4p9Sd1G-tuQCLcBGAs/s400/bukit-teletubis-foto-dari-%2540farizal_hakim.jpg',
#   'judul': 'Spot Foto menakjubkan di Ponorogo yg bakal bikin kamu tercengang',
#   'time': '7:52\u202fPM',
#   'url': 'https://raihanrnj.blogspot.com/2017/08/spot-foto-menakjubkan-di-ponorogo-yg.html'},
#  {'img': 'https://lh3.googleusercontent.com/blogger_img_proxy/AHs97-nzjCvJUp9aH9z-9VIM-L9OOTVAg55xHsvYOCU_nhTCygJSokscMY8-gSeIPRkhE_cnnT9yuPTrj8aXjQqOMjV0xuPVSV3ZRPELfSgNPmjN6tyL55ViD4DHZVeYx_gdcl_rBEqxBDDk3OObJtSwj7kWYUC30Tw14iA=s0-d',
#   'judul': '7 Misteri di Indonesia yang Belum Terpecahkan Hingga Saat Ini ',
#   'time': '8:06\u202fAM',
#   'url': 'https://raihanrnj.blogspot.com/2017/04/7-misteri-di-indonesia-yang-belum.html'},
#  {'img': 'https://i0.wp.com/www.dakwatuna.com/wp-content/uploads/2015/12/aliansi-negara-islam.jpg?resize=330%2C220',
# ...

# %%
# filename = '/content/drive/MyDrive/sainsdata/tugas/inspirational_quotes.csv'
# with open(filename, 'w', newline='') as f:
#     w = csv.DictWriter(f,['judul','p'])
#     w.writeheader()
#     for quote in quotes:
#         w.writerow(quote)

# %%
ps = soup.find_all('p') #find all p tags
for p in ps:
    print(p.get_text()) 
# p = ps.get_text()
# print(p)
# Out:
# iam wisi quam lorem vestibulum nec nibh, sollicitudin volutpat at libero litora, non adipiscing. Nul...
# iam wisi quam lorem vestibulum nec nibh, sollicitudin volutpat at libero litora, non adipiscing. Nul...
# iam wisi quam lorem vestibulum nec nibh, sollicitudin volutpat at libero litora, non adipiscing. Nul...
# iam 1989 wisi quam lorem vestibulum nec nibh, sollicitudin volutpat at libero litora, non adipiscing...
# iam wisi quam lorem vestibulum nec nibh, sollicitudin volutpat at libero litora, non adipiscing. Nul...
# 34 Negara Bentuk Aliansi Militer Islam, Indonesia Tidak Ambil Bagian
# Arab Saudi membentuk Aliansi Militer Islam bersama 34 Negara di kawasan teluk, Afrika dan Asia. (bisnis.com)
# dakwatuna.com – Riyadh.  Arab Saudi menggandeng negara negara yang berlatar belakang Islam membentuk aliansi militer Islam guna memerangi terorisme. Di aliansi tersebut terdapat 34 negara, baik dari kawasan Teluk, Afrika maupun bagian Asia lainnya.
# ...

# %%
ps = soup.find_all('div') #find all p tags
for p in ps:
    print(p.get_text().strip())
# Out:
# Menu
# Search
# Menu
#
# Search
# Blog
# Digital MarketingSEOPay Per ClicksEmail MarketingVideo MarketingContent MarketingSocial Media MarketingApps & ToolsWebsite
# Tech UpdatesCloud & DevOpsDewacloud PaaSDevelopment ToolsInternet of ThingsMobile ApplicationsServers & OSHosting & DomainWeb ApplicationContainersDatabasesKubernetes
# Cyber SecurityApplication SecurityCyber Security NewsSecurity AwarenessNetwork SecurityServer SecurityCloud SecurityCompany Updates
# ServicesCloud HostingCloud Server (VPS)Dewacloud PaaSDewaguard Cyber SecurityCloud Server CBTCloud BackupDomainSSL CertificatesDewatalks
# Search
# Blog
# Digital MarketingSEOPay Per ClicksEmail MarketingVideo MarketingContent MarketingSocial Media MarketingApps & ToolsWebsite
# Tech UpdatesCloud & DevOpsDewacloud PaaSDevelopment ToolsInternet of ThingsMobile ApplicationsServers & OSHosting & DomainWeb ApplicationContainersDatabasesKubernetes
# ...

# %%
ps = soup.find_all('span')

# %%
ps = soup.find_all('span') #find all p tags
for p in ps:
    print(p.get_text().strip())
# Out:
# Menu
#
# Search
# Search
#
# Search for:
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Blog » Website » 10 Jenis-Jenis Artikel Website yang Penting untuk Diketahui
# Blog
# Website
# 10 Jenis-Jenis Artikel Website yang Penting untuk Diketahui
# 10 Jenis-Jenis Artikel Website yang Penting untuk Diketahui
# Posted by
# Tutup
# 1. How To
# 2. Story Telling
# 3. Case Study
# 4. Listicle
# 5. Sumber
# 6. Review
# 7. Breaking News
# 8. Opini
# 9. Full Guide
# 10. Guide/This Is
# Sudah Tahu Apa Saja Jenis-Jenis Artikel?
# 1. How To
# 2. Story Telling
# 3. Case Study
# 4. Listicle
# 5. Sumber
# 6. Review
# 7. Breaking News
# 8. Opini
# 9. Full Guide
# 10. Guide/This Is
# Sudah Tahu Apa Saja Jenis-Jenis Artikel?

# %%
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
 
forecast_items = seven_day.find_all(class_="tombstone-container")
today = forecast_items[0]
print(today.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Today
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Today: Mostly sunny, with a high near 58. Windy, with a west northwest wind 8 to 18 mph increasing to 20 to 30 mph in the afternoon. Winds could gust as high as 41 mph. " class="forecast-icon" src="DualImage.php?i=bkn&amp;j=wind_sct" title="Today: Mostly sunny, with a high near 58. Windy, with a west northwest wind 8 to 18 mph increasing to 20 to 30 mph in the afternoon. Winds could gust as high as 41 mph. "/>
#  </p>
#  <p class="short-desc">
#   Partly Sunny
#   <br/>
#   then Mostly
#   <br/>
#   Sunny and
#   <br/>
#   Windy
#  </p>
#  <p class="temp temp-high">
#   High: 58 °F
#  </p>
# </div>

# %%
period = today.find(class_='period-name').get_text()
short_desc = today.find(class_='short-desc')
for br in short_desc.find_all('br'):
    br.replace_with('\n' + br.text)
short_desc = short_desc.get_text().replace('\n', ' ')
temp = today.find(class_='temp').get_text()
 
print(period)
#[print(line) for line in lines]
print(short_desc)
print(temp)
# Out:
# Today
# Partly Sunny then Mostly Sunny and Windy
# High: 58 °F

# %%
img = today.find('img') #return a dictionary, and the img attributes as the dictionary keys
desc = img["title"]
print(desc)
# Out:
# Today: Mostly sunny, with a high near 58. Windy, with a west northwest wind 8 to 18 mph increasing to 20 to 30 mph in the afternoon. Winds could gust as high as 41 mph.

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ['Today',
#  'Tonight',
#  'Wednesday',
#  'WednesdayNight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday']

# %%
short_descs = [sd for sd in seven_day.select(".tombstone-container .short-desc")]
for sd in short_descs:
    for br in sd.find_all('br'):
        br.replace_with('\n' + br.text)
short_descs = [sd.get_text().replace('\n', ' ') for sd in short_descs]
short_descs
# Out:
# ['Partly Sunny then Mostly Sunny and Windy',
#  'Increasing Clouds and Breezy',
#  'Partly Sunny then Partly Sunny and Breezy',
#  'Chance Rain',
#  'Rain Likely',
#  'Showers Likely',
#  'Chance Rain',
#  'Slight Chance Rain then Partly Cloudy',
#  'Mostly Sunny']

# %%
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
temps
# Out:
# ['High: 58 °F',
#  'Low: 42 °F',
#  'High: 51 °F',
#  'Low: 40 °F',
#  'High: 50 °F',
#  'Low: 39 °F',
#  'High: 49 °F',
#  'Low: 38 °F',
#  'High: 53 °F']

# %%
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
descs
# Out:
# ['Today: Mostly sunny, with a high near 58. Windy, with a west northwest wind 8 to 18 mph increasing to 20 to 30 mph in the afternoon. Winds could gust as high as 41 mph. ',
#  'Tonight: Increasing clouds, with a low around 42. Breezy, with a northwest wind 20 to 29 mph, with gusts as high as 46 mph. ',
#  'Wednesday: Partly sunny, with a high near 51. Breezy, with a west northwest wind 16 to 22 mph, with gusts as high as 29 mph. ',
#  'Wednesday Night: A 30 percent chance of rain after 10pm.  Mostly cloudy, with a low around 40. West northwest wind 10 to 15 mph, with gusts as high as 23 mph.  New precipitation amounts of less than a tenth of an inch possible. ',
#  'Thursday: Rain likely, mainly after 10am.  Mostly cloudy, with a high near 50. Southwest wind 8 to 13 mph, with gusts as high as 18 mph.  Chance of precipitation is 60%. New precipitation amounts between a tenth and quarter of an inch possible. ',
# ...

# %%
import pandas as pd
weather = pd.DataFrame({
    "period": periods,
    "short_desc": short_descs,
    "temp": temps,
    "desc": descs
})
 
weather
# Out:
#            period                                 short_desc         temp  \
# 0           Today   Partly Sunny then Mostly Sunny and Windy  High: 58 °F
# 1         Tonight               Increasing Clouds and Breezy   Low: 42 °F
# 2       Wednesday  Partly Sunny then Partly Sunny and Breezy  High: 51 °F
# 3  WednesdayNight                                Chance Rain   Low: 40 °F
# 4        Thursday                                Rain Likely  High: 50 °F
# 5   ThursdayNight                             Showers Likely   Low: 39 °F
# 6          Friday                                Chance Rain  High: 49 °F
# 7     FridayNight      Slight Chance Rain then Partly Cloudy   Low: 38 °F
# 8        Saturday                               Mostly Sunny  High: 53 °F
#
#                                                 desc
# 0  Today: Mostly sunny, with a high near 58. Wind...
# 1  Tonight: Increasing clouds, with a low around ...
# 2  Wednesday: Partly sunny, with a high near 51. ...
# ...

# %%
temp_nums = weather["temp"].str.extract('(\d+)', expand=False)
temp_nums
# Out:
# 0    58
# 1    42
# 2    51
# 3    40
# 4    50
# 5    39
# 6    49
# 7    38
# 8    53
# Name: temp, dtype: object

# %%
weather["temp_num"] = temp_nums.astype('int')
weather
# Out:
#            period                                 short_desc         temp  \
# 0           Today   Partly Sunny then Mostly Sunny and Windy  High: 58 °F
# 1         Tonight               Increasing Clouds and Breezy   Low: 42 °F
# 2       Wednesday  Partly Sunny then Partly Sunny and Breezy  High: 51 °F
# 3  WednesdayNight                                Chance Rain   Low: 40 °F
# 4        Thursday                                Rain Likely  High: 50 °F
# 5   ThursdayNight                             Showers Likely   Low: 39 °F
# 6          Friday                                Chance Rain  High: 49 °F
# 7     FridayNight      Slight Chance Rain then Partly Cloudy   Low: 38 °F
# 8        Saturday                               Mostly Sunny  High: 53 °F
#
#                                                 desc  temp_num
# 0  Today: Mostly sunny, with a high near 58. Wind...        58
# 1  Tonight: Increasing clouds, with a low around ...        42
# ...

# %%
weather["temp_num"].mean()
# Out:
# 46.666666666666664

# %%
is_night = weather["temp"].str.contains("Low")
weather["is_night"] = is_night
is_night
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# Name: temp, dtype: bool

# %%
weather[is_night]
# Out:
#            period                             short_desc        temp  \
# 1         Tonight           Increasing Clouds and Breezy  Low: 42 °F
# 3  WednesdayNight                            Chance Rain  Low: 40 °F
# 5   ThursdayNight                         Showers Likely  Low: 39 °F
# 7     FridayNight  Slight Chance Rain then Partly Cloudy  Low: 38 °F
#
#                                                 desc  temp_num  is_night
# 1  Tonight: Increasing clouds, with a low around ...        42      True
# 3  Wednesday Night: A 30 percent chance of rain a...        40      True
# 5  Thursday Night: Showers likely and possibly a ...        39      True
# 7  Friday Night: A slight chance of rain before 1...        38      True

# %%
from pathlib import Path  
filepath = Path('/content/drive/MyDrive/sainsdata/filcsv/negeri.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
weather.to_csv(filepath)
