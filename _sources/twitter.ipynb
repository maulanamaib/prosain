# %% [markdown]
# # Crawling Twitter

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# Out:
# Cloning into 'twint'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 47 (delta 3), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), 42.93 KiB | 2.86 MiB/s, done.

# %%
# %cd twint
# Out:
# /content/twint

# %%
# !pip3 install . -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/twint
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.0/266.0 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.4/385.4 KB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 KB 5.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 KB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 9.8 MB/s eta 0:00:00
# ...
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=38870 sha256=521fa480ff3a750d7c18139271b242f137db60c737dcc1e7608e17754ff8fd49
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k_pu9wa8/wheels/a9/70/09/93062f64eee119ab310a33bae425d98678f627d1dc1b667e8f
# ...

# %%
# !pip install aiohttp==3.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 16.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.2
#     Uninstalling async-timeout-4.0.2:
#       Successfully uninstalled async-timeout-4.0.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.4
#     Uninstalling aiohttp-3.8.4:
#       Successfully uninstalled aiohttp-3.8.4
# ...

# %%
# !pip3 install nest_asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nest_asyncio
nest_asyncio.apply() #digunakan sekali untuk mengaktifkan tindakan serentak dalam notebook jupyter.
import twint #untuk import twint

# %%
c = twint.Config()
c.Search = '#Ganjar'
c.Pandas = True
c.Limit = 500
c.Store_csv = True
c.Store_object = True
c.Pandas = True
c.Lang='en'
# c.Format = "Twitter id: {id}"
# c.Custom["tweet"] = ["tweet"]
# c.Output = "dataGanjar.csv"
twint.run.Search(c)
# Out:
# 1628073724066017281 2023-02-21 16:46:38 +0000 <RenaHoston178> Berdasarkan perhitungan elektronik-Pencatatan dan Pelaporan Gizi Berbasis Masyarakat (ePPGBM), angka stunting di Jateng berada di angkat 24,4 persen pada 2018. Setahun kemudian, angkanya turun menjadi 18,3 persen.  #SahabatGanjar #Ganjar #ganjarpranowo  https://t.co/PrvM7kReiI
# 1628073711457939460 2023-02-21 16:46:35 +0000 <RenaHoston178> Gubernur Jawa Tengah Ganjar Pranowo berhasil mengurangi angka stunting sebesar 51 persen dalam kurun waktu empat tahun. .. #SahabatGanjar #Ganjar #ganjarpranowo  https://t.co/fvD6TsmjkG
# 1628073015434178560 2023-02-21 16:43:49 +0000 <putuagenggribig> JURUS PEMERINTAH ATASI INFLASI #GolkarIndonesia  #AirlanggaHartarto #UUCiptaKerja #Sambo #bharadaE #kerjanyata #aniesbaswedan #pemilu #jokowi #PSI #Gerindra #prabowo #ganjar #politikidentitas #puanmaharani #ridwankamil #pdip #nasdem #ekonomi #kpk #koalisi #pks #demokrat  https://t.co/RX5mntg9Qh
# ...

# %%
from logging import PlaceHolder
Tweets_df = twint.storage.panda.Tweets_df
data=Tweets_df.head(500)
data
# Out:
#                       id      conversation_id    created_at  \
# 0    1628073724066017281  1628073711457939460  1.676998e+12
# 1    1628073711457939460  1628073711457939460  1.676998e+12
# 2    1628073015434178560  1628073015434178560  1.676998e+12
# 3    1628047864105680896  1628047864105680896  1.676992e+12
# 4    1628045934679699457  1628045934679699457  1.676991e+12
# ..                   ...                  ...           ...
# 175  1627614543303315458  1627614538496638976  1.676889e+12
# 176  1627614538496638976  1627614538496638976  1.676889e+12
# 177  1627611741592129537  1627611741592129537  1.676888e+12
# 178  1627611140531568642  1627603449373401090  1.676888e+12
# 179  1627611007836385280  1627603288286957570  1.676888e+12
#
#                     date timezone place  \
# 0    2023-02-21 16:46:38    +0000
# 1    2023-02-21 16:46:35    +0000
# 2    2023-02-21 16:43:49    +0000
# 3    2023-02-21 15:03:53    +0000
# 4    2023-02-21 14:56:13    +0000
# ...

# %%
data.to_csv("negeri_pajak.csv", index=False)

# %%
from pathlib import Path  
filepath = Path('/content/drive/MyDrive/sainsdata/filcsv/Ganjar.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
data.to_csv(filepath)

# %%
import joblib
filename = '/content/drive/MyDrive/sainsdata/tugas/caca.csv'
joblib.dump(data, filename)
# Out:
# ['/content/drive/MyDrive/sainsdata/tugas/caca.csv']
